# %% [markdown]
# I found out that if I change the field number for (RA, DEC)=(139.463333333,-0.279166666667), from 128 to 127 then the galaxy stil stays in my field of view. If I mosaic these two together, I should get a good centered image. (this is tested in cam_col_test_3).Then recenter the image so that the given RA,DEC of galaxy is at center of image.

# %%
from IPython.core.display import Image

# %% [markdown]
# May have to add in background rectification procedures, if we end up coAdding many images and the brightness in the overlapping strip goes weird. Right now it looks fine.

# %% [markdown]
# I'm using mSubImage to "crop" my mosaic. default height (y) is equal to width which is set to two times x. After running the script, it didn't seem to crop the picture at all. So I'm manually testing whether the radius value of galaxy is right, eventually I need to refer to de Valeuleurs' original paper or the Corwin correction.

# %%
Image(filename="camcoltest4_cropped.jpg")

# %%
Image("camcoltest4_cropped.jpg")

# %% [markdown]
# Not sure why the rightmost edge is cropped off, there shouldn't have been overlaying issue because there was only one image.

# %% [markdown]
# For the next image that I generate, I am going to try to download it using the URL instead of manually download using Single Search Tools

# %% [markdown]
# 158.147083333,65.0413888889
#
# - 1412	3	96
# - 'RERUN' should be replaced by the appropriate imaging reduction number (currently '301')
# -  'RUN6' should be replaced by the zero-padded, 6-digit run number and 'FIELD' should be replaced by the zero-padded, 4-digit field number.

# %% [markdown]
# #### ***Lesson of the day: when creating new galaxies MAKE SURE you change ALL 6 values for the galaxy (camcol,field, run , RA, DEC, radius)
# This will not throw an error until very late in the mosaicing stage. It will secretly produce no projected images without telling you, and secretly produce an empty pimages.tbl.

# %%
Image("camcoltest4.jpg")

# %%
mkdir 163.129583333,7.22444444444

# %%
cd 163.129583333,7.22444444444/
# Out:
# /Users/doris/Desktop/GSoC2014/workarea-rc3-project/notebooks/163.129583333,7.22444444444

# %%
import montage_wrapper as montage
import os
import shutil

DEBUG = True
CUTOFF =False 
run=3015
camcol=4
field=327

ra=163.129583333
dec= 7.22444444444
radius=  0.758577575029*2
bands=['u','g','r','i','z']
for ele in bands:
	band =ele
	out = "frame-"+str(band)+"-00"+str(run)+"-"+str(camcol)+"-0"+str(field)
	os.system("wget http://data.sdss3.org/sas/dr10/boss/photoObj/frames/301/"+str(run)+"/"+ str(camcol) +"/"+out+".fits.bz2")
	os.system("bunzip2 "+out+".fits.bz2")
	if (CUTOFF) :
		out2 = "frame-"+str(band)+"-00"+str(run)+"-"+str(camcol)+"-0"+str(field-1)
		os.system("wget http://data.sdss3.org/sas/dr10/boss/photoObj/frames/301/"+str(run)+"/"+ str(camcol) +"/"+out2+".fits.bz2")
		os.system("bunzip2 "+out2+".fits.bz2")
	os.mkdir (band)
	os.chdir(band)
	os.mkdir ("raw")
	os.mkdir ("projected")
	os.chdir("..")
	shutil.move(out+".fits",band+"/raw/" )
	if(CUTOFF): shutil.move(out2+".fits",band+"/raw/" )
	os.chdir(band)
	if (DEBUG) : print("Creating mosaic for " +" "+ band + " band.")
	montage.mImgtbl("raw","images.tbl")
	montage.mHdr(str(ra)+" "+str(dec),radius,out+".hdr")
	if (DEBUG): print ("Reprojecting images")
	#Sometimes you can't find the files and result in images.tbl => empty doc
	#need to put data file inside raw AND unzip it so that Montage detect that it is a fit file
	os.chdir("raw")
	montage.mProjExec("../images.tbl","../"+out+".hdr","../projected", "../stats.tbl") 
	os.chdir("..")
	montage.mImgtbl("projected","pimages.tbl")
	#mAdd coadds the reprojected images using the FITS header template and mImgtbl list.
	os.chdir("projected")
	montage.mAdd("../pimages.tbl","../"+out+".hdr","SDSS_"+out+".fits")
	montage.mSubimage("SDSS_"+out+".fits","SDSS_"+out+"cropped.fits",
		ra,dec,0.05033333333400003)
	shutil.move("SDSS_"+out+"cropped.fits",os.getcwd()[:-11] )#if change to :-11 then move out of u,g,r,i,z directory, may be more convenient for mJPEG
	if (DEBUG) : print ("Completed Mosaic for " + band)
	os.chdir("../..")
# Superimposing R,G,B image mosaics into JPEG
os.system("mJPEG -blue "+ "SDSS_frame-"+"i"+"-00"+str(run)+"-"+str(camcol)+"-0"+str(field)+ "cropped.fits "+ " -1s 99.999% gaussian-log \
        -green SDSS_frame-"+"g"+"-00"+str(run)+"-"+str(camcol)+"-0"+str(field)+"cropped.fits "+" -1s 99.999% gaussian-log \
        -red SDSS_frame-"+"r"+"-00"+str(run)+"-"+str(camcol)+"-0"+str(field)+"cropped.fits "+" -1s 99.999% gaussian-log \
        -out camcoltest4.jpg")
if (DEBUG) : print ("Completed Mosaic")
# Out:
# Creating mosaic for  u band.
# Reprojecting images
# Completed Mosaic for u
# Creating mosaic for  g band.
# Reprojecting images
# Completed Mosaic for g
# Creating mosaic for  r band.
# Reprojecting images
# Completed Mosaic for r
# Creating mosaic for  i band.
# Reprojecting images
# Completed Mosaic for i
# Creating mosaic for  z band.
# Reprojecting images
# Completed Mosaic for z
# Completed Mosaic

# %%
Image("camcoltest4.jpg")

# %% [markdown]
# ## g,r,i, Color problem

# %% [markdown]
# - Ordering of R,G,B => g,r,i
# - mJPEG parameter value

# %%
  mJPEG -blue  SDSS_frame-g-001239-3-0128.fits -1s 99.999% gaussian-log \
        -green SDSS_frame-r-001239-0128.fits -1s 99.999% gaussian-log \
        -red SDSS_frame-i-001239-0128.fits -1s 99.999% gaussian-log \
        -out SDSS_001239-3-0128_2.jpg

# %%
Image(filename="camcoltest3.jpg")

# %%
  mJPEG -blue  SDSS_frame-i-001239-3-0128.fits -1s 99.999% gaussian-log \
        -green SDSS_frame-g-001239-0128.fits -1s 99.999% gaussian-log \
        -red SDSS_frame-r-001239-0128.fits -1s 99.999% gaussian-log \
        -out SDSS_001239-3-0128_2.jpg

# %%
Image("camcoltest3_r2r_g2g_b2i.jpg")

# %% [markdown]
# Things to work on later
#
# - remove "cropped"
# - 4 digit and 6 digit zero padding using NumberFormat or something ?
# - triangular cutoff for the last 2 images (?)
# - scientific-color calibration (g,r,i ordering?)
# - radius of galaxies (look at deValcouer's original paper or Corwin's modifcation to figure out what the parameter is; dont forget to convert arcmin to degree)
# - background rectification necessary? (only 2, maximum 4 images)
