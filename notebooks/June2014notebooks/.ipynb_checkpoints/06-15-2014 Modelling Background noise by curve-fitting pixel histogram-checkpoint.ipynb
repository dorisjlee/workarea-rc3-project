# %%
from scipy.optimize import curve_fit
from scipy.stats import norm
import pyfits
from matplotlib import pyplot as pyplt
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from IPython.core.display import Image
import os
# %matplotlib inline

# %%
fitsImage = pyfits.open("stiff.fits")
image = fitsImage[0].data

# %%
import numpy
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
image = fitsImage[0].data
# Define some test data which is close to Gaussian
# data = numpy.random.normal(size=10000)
data = list(image.ravel())
#print (data)
hist, bin_edges = numpy.histogram(data, density=True)
bin_centres = (bin_edges[:-1] + bin_edges[1:])/2

# Define model function to be used to fit to the data above:
def gauss(x, *p):
    A, mu, sigma = p
    return A*numpy.exp(-(x-mu)**2/(2.*sigma**2))

# p0 is the initial guess for the fitting coefficients (A, mu and sigma above)
p0 = [1., 0., 1.]

coeff, var_matrix = curve_fit(gauss, bin_centres, hist, p0=p0)

# Get the fitted curve
hist_fit = gauss(bin_centres, *coeff)

plt.plot(bin_centres, hist, label='Test data')
plt.plot(bin_centres, hist_fit, label='Fitted data')

# print ('Fitted mean = ', coeff[1])
# print ('Fitted standard deviation = ', coeff[2])

plt.show()
my_hist_plot(fitsImage)
# Out:
# Fitted mean =  0.0
# Fitted standard deviation =  1.0
# (11.331539848023365, 20.405730798910685)

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm
image = fitsImage[0].data
data = list(image.ravel())
(mu,sigma) = norm.fit(data)
print (mu,sigma)
#Mu is the mean, and sigma is one standard deviation. 
plt.figure(1)
n,bins,patches=plt.hist(data,50,normed=1,facecolor='green',align='mid')#number of bin in histo =50
y = mlab.normpdf(bins,mu,sigma)
plt.plot(bins,y,'r--',linewidth=2)
# Out:
# 11.331539848 20.4057307989
