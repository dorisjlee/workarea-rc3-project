# %%
original 0.08875,-2.61055555556


Biggest Galaxy with radius 14.297 pixels!
Radii: 0.00157204809577 degrees
rc3: 0.08875 , updated: 0.1046864 
rc3: -2.61055555556 , updated: -2.6238813 
rc3: 0.0102522397773 , updated: 0.00157204809577

# %%
from IPython.core.display import Image
Image("Screen Shot 2014-06-25 at 3.28.09 PM.png")

# %%
cd ../../../..
# Out:
# /Users/dorislee/Desktop

# %% [markdown]
# So I shrunk the initial_run mosaicing radius to 2*rc3_radius so that there is less possible "distractions"

# %%
Image("Screen Shot 2014-06-25 at 3.53.07 PM.png")

# %% [markdown]
# I think the radius is wrong

# %% [markdown]
# The radius (pix to deg conversion) is wrong, and off by one order of magnitude.

# %% [markdown]
# On the sdss site http://skyserver.sdss3.org/dr10/en/tools/chart/chartinfo.aspx
#     arcsec/pixel (the natural scale of SDSS is 0.396127)

# %% [markdown]
# 0.396127 *1/3600 #degree / pixel
# 1 arc second =1/3600 degree = 0.000277777778 degree

# %%
0.396127*1/3600
# Out:
# 0.00011003527777777778

# %%
14.297*0.00011003527777777778
# Out:
# 0.001573174366388889

# %% [markdown]
# http://skyserver.linea.gov.br/dr10/en/help/docs/api.aspx
# scale is the scale of the image in arcsec per pixel, 0.4 is default

# %% [markdown]
# The radius conversion is still a persisting issue. I am now unit testing all the possible cases, after teting that they work in all the cases . I will start establishing the rc3 class object which enables iterative count.

# %% [markdown]
# __Tested Case where RC3 is identify in the initial image__
# => directly go and mosaic_all_band
#
#
# Biggest Galaxy with radius 5.251 pixels!
# Radii: 0.000577381587108 degrees
# rc3: 0.580833333333 , updated: 0.5798865
# rc3: 12.9719444444 , updated: +12.9715943
# rc3: 0.0100188703085 , updated: 0.000577381587108
#
#
#
# Resulting mosaic very centered, Sucessful test case
#
# Also conducted this on several other galaxy, also sucessful
#
# I am not sure how this is done with a wrong radius (but will figure that out later)

# %% [markdown]
# __Tested Case where no RC3 lie in field__
#
# Sucessfully grab more field
#
# Not sure about result because it keeps getting a larger and larger margin until timeout because it is unstoppable by iteration
# or because out updated_radius is wrong which causes our margin to be wrong

# %% [markdown]
# __Test Edge Cases, initially no RC3 in field but found RC3 after several iteration__
#
# - No Warning or Error thrown
# - mosaics produce (no field englarging was necessary)
#     0.1040707,+7.8478651
#     0.2500879,+6.2353761
#     0.7420218,+4.2062764
#     0.8600314,+27.3573389
# - mosaics produced (after enlarging field , after 1 iteration)
#     0.2674770,+4.4999796
# - image not properly centered

# %%
Working on 34th RC3 Galaxy at 200.220416667,57.6427777778
------------------mosaic_band----------------------
Querying data that lies inside margin
["<html><head></head><body><h1>ERROR</h1><h2>Violation of PRIMARY KEY constraint 'pk_RecentQueries_ipAddr_lastQuer'. Cannot insert duplicate key in object 'dbo.RecentQueries'. The duplicate key value is (98.248.228.235, Jun 25 2014  9:55PM).\r\n", 'The statement has been terminated.</h2><pre>   at System.Data.SqlClient.SqlConnection.OnError(SqlException exception, Boolean breakConnection)\r\n', '   at System.Data.SqlClient.TdsParser.ThrowExceptionAndWarning()\r\n', '   at System.Data.SqlClient.TdsParser.Run(RunBehavior runBehavior, SqlCommand cmdHandler, SqlDataReader dataStream, BulkCopySimpleResultSet bulkCopyHandler, TdsParserStateObject stateObj)\r\n', '   at System.Data.SqlClient.SqlDataReader.ConsumeMetaData()\r\n', '   at System.Data.SqlClient.SqlDataReader.get_MetaData()\r\n', '   at System.Data.SqlClient.SqlCommand.FinishExecuteReader(SqlDataReader ds, RunBehavior runBehavior, String resetOptionsString)\r\n', '   at System.Data.SqlClient.SqlCommand.RunExecuteReaderTds(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, Boolean async)\r\n', '   at System.Data.SqlClient.SqlCommand.RunExecuteReader(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, String method, DbAsyncResult result)\r\n', '   at System.Data.SqlClient.SqlCommand.RunExecuteReader(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, String method)\r\n', '   at System.Data.SqlClient.SqlCommand.ExecuteReader(CommandBehavior behavior, String method)\r\n', '   at System.Data.SqlClient.SqlCommand.ExecuteReader()\r\n', '   at SkyServer.ResponseAux.getDataTable(SqlConnection oConn, String cmd, Int32 timeout) in D:\\Projects\\skyServer\\misc\\ResponseAux.cs:line 235\r\n', '   at SkyServer.Tools.Search.X_SQL.ProcessRequest() in D:\\Projects\\skyServer\\en\\tools\\search\\X_SQL.aspx.cs:line 100</pre></body></html>']
Traceback (most recent call last):
  File "update.py", line 225, in <module>
    initial_run()
  File "update.py", line 222, in initial_run
    mosaic_band('r',ra,dec,2*radius,radius,pgc)
  File "update.py", line 37, in mosaic_band
    list[2]= list[2][:-1]
IndexError: list index out of range

# %%
Working on 72th RC3 Galaxy at 1.68333333333,-6.63527777778
------------------mosaic_band----------------------
Querying data that lies inside margin
["<html><head></head><body><h1>ERROR</h1><h2>Violation of PRIMARY KEY constraint 'pk_RecentQueries_ipAddr_lastQuer'. Cannot insert duplicate key in object 'dbo.RecentQueries'. The duplicate key value is (98.248.228.235, Jun 25 2014 10:02PM).\r\n", 'The statement has been terminated.</h2><pre>   at System.Data.SqlClient.SqlConnection.OnError(SqlException exception, Boolean breakConnection)\r\n', '   at System.Data.SqlClient.TdsParser.ThrowExceptionAndWarning()\r\n', '   at System.Data.SqlClient.TdsParser.Run(RunBehavior runBehavior, SqlCommand cmdHandler, SqlDataReader dataStream, BulkCopySimpleResultSet bulkCopyHandler, TdsParserStateObject stateObj)\r\n', '   at System.Data.SqlClient.SqlDataReader.ConsumeMetaData()\r\n', '   at System.Data.SqlClient.SqlDataReader.get_MetaData()\r\n', '   at System.Data.SqlClient.SqlCommand.FinishExecuteReader(SqlDataReader ds, RunBehavior runBehavior, String resetOptionsString)\r\n', '   at System.Data.SqlClient.SqlCommand.RunExecuteReaderTds(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, Boolean async)\r\n', '   at System.Data.SqlClient.SqlCommand.RunExecuteReader(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, String method, DbAsyncResult result)\r\n', '   at System.Data.SqlClient.SqlCommand.RunExecuteReader(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, String method)\r\n', '   at System.Data.SqlClient.SqlCommand.ExecuteReader(CommandBehavior behavior, String method)\r\n', '   at System.Data.SqlClient.SqlCommand.ExecuteReader()\r\n', '   at SkyServer.ResponseAux.getDataTable(SqlConnection oConn, String cmd, Int32 timeout) in D:\\Projects\\skyServer\\misc\\ResponseAux.cs:line 235\r\n', '   at SkyServer.Tools.Search.X_SQL.ProcessRequest() in D:\\Projects\\skyServer\\en\\tools\\search\\X_SQL.aspx.cs:line 100</pre></body></html>']
Data contain unclean images
Traceback (most recent call last):
  File "update.py", line 225, in <module>
    initial_run()
  File "update.py", line 222, in initial_run
    mosaic_band('r',ra,dec,2*radius,radius,pgc)
  File "update.py", line 37, in mosaic_band
    list[2]= list[2][:-1]
IndexError: list index out of range

# %%
Working on 61th RC3 Galaxy at 200.930416667,30.5638888889
------------------mosaic_band----------------------
Querying data that lies inside margin
Traceback (most recent call last):
  File "update.py", line 225, in <module>
    initial_run()
  File "update.py", line 222, in initial_run
    mosaic_band('r',ra,dec,2*radius,radius,pgc)
  File "update.py", line 24, in mosaic_band
    result = sqlcl.query( "SELECT distinct run,camcol,field FROM PhotoObj WHERE  ra between {0}-{1} and  {0}+{1}and dec between {2}-{3} and  {2}+{3}".format(str(ra),str(margin),str(dec),str(margin))).readlines()
  File "/Users/dorislee/Desktop/rfits/sqlcl.py", line 41, in query
    return urllib.urlopen(url+'?%s' % params)    
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.py", line 87, in urlopen
    return opener.open(url)
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.py", line 208, in open
    return getattr(self, name)(url)
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.py", line 346, in open_http
    errcode, errmsg, headers = h.getreply()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 1117, in getreply
    response = self._conn.getresponse()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 1045, in getresponse
    response.begin()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 409, in begin
    version, status, reason = self._read_status()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 365, in _read_status
    line = self.fp.readline(_MAXLINE + 1)
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/socket.py", line 476, in readline
    data = self._sock.recv(self._rbufsize)
IOError: [Errno socket error] [Errno 60] Operation timed out
>>>

# %%
Working on 111th RC3 Galaxy at 3.05,41.7361111111
------------------mosaic_band----------------------
Querying data that lies inside margin
Traceback (most recent call last):
  File "update.py", line 225, in <module>
    initial_run()
  File "update.py", line 222, in initial_run
    mosaic_band('r',ra,dec,2*radius,radius,pgc)
  File "update.py", line 24, in mosaic_band
    result = sqlcl.query( "SELECT distinct run,camcol,field FROM PhotoObj WHERE  ra between {0}-{1} and  {0}+{1}and dec between {2}-{3} and  {2}+{3}".format(str(ra),str(margin),str(dec),str(margin))).readlines()
  File "/Users/dorislee/Desktop/GSoC2014/workarea-rc3-project/withSExtractor/rfits/sqlcl.py", line 41, in query
    return urllib.urlopen(url+'?%s' % params)    
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.py", line 87, in urlopen
    return opener.open(url)
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.py", line 208, in open
    return getattr(self, name)(url)
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib.py", line 346, in open_http
    errcode, errmsg, headers = h.getreply()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 1117, in getreply
    response = self._conn.getresponse()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 1045, in getresponse
    response.begin()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 409, in begin
    version, status, reason = self._read_status()
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.py", line 365, in _read_status
    line = self.fp.readline(_MAXLINE + 1)
  File "/System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/socket.py", line 476, in readline
    data = self._sock.recv(self._rbufsize)
IOError: [Errno socket error] [Errno 60] Operation timed out
>>>

# %% [markdown]
# Sucessful test case for Case 3 (recursive call on source extraction after building rc3 class )
# SDSS_r_1.025_7.3575.fits

# %%
uniq rc3_galaxies_unclean| tee rc3_galaxies_unclean
