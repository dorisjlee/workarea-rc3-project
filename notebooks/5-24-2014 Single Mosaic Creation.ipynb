# %% [markdown]
# Trying to figure out how exactly mJPEG is done
#
# - changing ordering of color seem to change image color

# %%
cd cam_col_test2/
# Out:
# /Users/doris/Desktop/GSoC2014/workarea-rc3-project/notebooks/cam_col_test2

# %%
ls
# Out:
# SDSS_001239-3-0128.jpg           frame-i-001239-3-0128.fits.bz2
# SDSS_001239-3-0128_2.jpg         frame-r-001239-0128.hdr
# SDSS_frame-g-001239-3-0128.fits  frame-u-001239-3-0128.fits.bz2
# SDSS_frame-i-001239-0128.fits    frame-z-001239-3-0128.fits.bz2
# SDSS_frame-r-001239-0128.fits    g/
# SDSS_frame-u-001239-3-0128.fits  i/
# SDSS_frame-z-001239-3-0128.fits  r/
# Using_CamCol_DR10_Data.py        u/
# frame-g-001239-3-0128.fits.bz2   z/

# %% [raw]
#   mJPEG -blue  SDSS_frame-g-001239-3-0128.fits -1s 99.999% gaussian-log \
#         -green SDSS_frame-r-001239-0128.fits -1s 99.999% gaussian-log \
#         -red SDSS_frame-i-001239-0128.fits -1s 99.999% gaussian-log \
#         -out SDSS_001239-3-0128_2.jpg

# %%
from IPython.core.display import Image 
Image(filename="SDSS_001239-3-0128.jpg")

# %% [raw]
#   mJPEG -blue  SDSS_frame-g-001239-3-0128.fits -1s 99.999% gaussian-log \
#         -green SDSS_frame-r-001239-0128.fits -1s 99.999% gaussian-log \
#         -red SDSS_frame-i-001239-0128.fits -1s 99.999% gaussian-log \
#         -out SDSS_001239-3-0128_2.jpg

# %%
Image(filename="SDSS_001239-3-0128_2.jpg")

# %%
#What the SDSS SAS web server displays http://data.sdss3.org/fields/raDec?ra=139.463333333&dec=-0.279166666667
Image(filename="Single_Search_Image_search.jpg")

# %% [markdown]
# Trying to figure out the parameters
#
# - http://montage.ipac.caltech.edu/docs/mJPEG.html
# - http://skyserver.sdss.org/dr1/en/proj/advanced/color/sdssfilters.asp
# - http://www.sdss3.org/dr9/imaging/imaging_basics.php
