# %%
# This code only runs on python 2 (source deactivate) not python 3. (source activate py33dev)
# I made some modification so that it works in python 3.3
counter = 0

ralist = []
declist = []
radiuslist = []

f= open('rc3.txt','r')
print (f)
for line in f:
    #print (line)
    counter = counter + 1
    print (counter)
    if counter > 15:
        break
        
    if counter != 5 and counter != 6 and counter != 7 and counter != 11:
        
        x = float(line[0:2])
        y = float(line[2:4])
        z = float(line[4:8])
         
        sign = line[9]
        decval = float(line[10:12]) 
        print (decval)
        m = float(line[12:14])
        
##     #   if line[14] != ' ' and line[15] != ' ':        
        n = float(line[14:16])
        
        # testval = float(line[171:175])
        rad = 10**(float(line[171:175]))
        radius = rad/10
        
        ra = 15*x + (y/4) + (z/240) 
##      #  if line[14] != ' ' and line[15] != ' ':
        dec = decval + (m/60) + (n/3600)   
##      else:
#        dec = decval + (m/60)
        
        if sign == '-':
           dec = -1*dec 
              
        ralist.append(ra)
        declist.append(dec)
        radiuslist.append(radius)
        
       # print ra, dec
       # print radius 
#Parenthesis for py2 --> py3 compatiblity
print (ralist)
print (declist)
print (radiuslist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-66f81c22f2e4> in <module>()
#      28
#      29 ##     #   if line[14] != ' ' and line[15] != ' ':
# ---> 30         n = float(line[14:16])
#      31
#      32         # testval = float(line[171:175])
#
# ValueError: could not convert string to float:
# <_io.TextIOWrapper name='rc3.txt' mode='r' encoding='UTF-8'>
# 1
# 47.0
# 2
# 6.0
# 3
# 2.0
# 4
# 80.0
# 5
# 6
# 7
# 8
# 40.0
# 9
# 20.0
# 10
# 28.0
# 11
# 12
# 28.0
# 13
# 28.0
# 14
# 47.0
# 15
# 40.0
# 16
# 20.0

# %%
# This code only runs on python 2 (source deactivate) not python 3. (source activate py33dev)
# I made some modification so that it works in python 3.3


ralist = []
declist = []
radiuslist = []

f= open('rc3.txt','r')
counter = 0
#print (f)
for line in f:
    print (line)
    counter = counter + 1
    print (counter)
    if counter > 15:
        break
        #counter = 1
        
        
    if counter != 5 and counter != 6 and counter != 7 and counter != 11:
        
        x = float(line[0:2])
        y = float(line[2:4])
        z = float(line[4:8])
        print ('x: '+str(x))
        print ('y: '+str(y))
        print ('z: '+str(z))
        sign = line[9]
        decval = float(line[10:12]) 
        print (decval)
        m = float(line[12:14])
        print ('m: '+str(m))
        
##     #   if line[14] != ' ' and line[15] != ' ':        
        n = float(line[14:16])
        print ('n: '+str(n))
        # testval = float(line[171:175])
        rad = 10**(float(line[171:175]))
        radius = rad/10
        
        ra = 15*x + (y/4) + (z/240) 
##      #  if line[14] != ' ' and line[15] != ' ':
        dec = decval + (m/60) + (n/3600)   
##      else:
#        dec = decval + (m/60)
        
        if sign == '-':
           dec = -1*dec 
              
        ralist.append(ra)
        declist.append(dec)
        radiuslist.append(radius)
        print('--------------------------------------------------------------------------------')
       # print ra, dec
       # print radius 
#Parenthesis for py2 --> py3 compatiblity
print (ralist)
print (declist)
print (radiuslist)
# Out:
# 0000 1.8 +471628 235728.5 +465946 113.96 -14.70 341.64  20.73 A   2357+47  UGC 12889                     PGC    2    .SBT3.. U      3.0  .7            1.33  .04  .07  .05 1.38          165            13.4  .3  12.74                            15.19 .1                                                 2.41  .10 .04  .52 455 11 464  8  5017  9            5217  4751
#
# 1
# x: 0.0
# y: 0.0
# z: 1.8
# 47.0
# m: 16.0
# n: 28.0
# --------------------------------------------------------------------------------
# 0000 8.7 -062229 235734.9 -063911  90.19 -65.93 286.42  11.35              MCG -1- 1- 16                 PGC   12    .S..1P? E      1.0 1.8  7.0 1.3 1 1.18  .05  .74  .05 1.19                                                                                                                                   .75 .37  .09                         6493  60  6581  6147
#
# 2
# x: 0.0
# y: 0.0
# z: 8.7
# 6.0
# m: 22.0
# n: 29.0
# --------------------------------------------------------------------------------
# 000021.3 -023638 235747.5 -025320  94.25 -62.60 290.12  12.41              MCG -1- 1- 20                 PGC   23    .E+..*. E     -4.0 1.2            1.15  .06  .25  .05 1.09                                                                                                                                   .00      .12
#
# 3
# x: 0.0
# y: 0.0
# z: 21.3
# 2.0
# m: 36.0
# n: 38.0
# --------------------------------------------------------------------------------
# 000022.5 -804730 235747.0 -810412 305.44 -36.09 215.65 -13.35              ESO   12- 12   IRAS23577-8104 PGC   30    PSXT4P. S      4.0  .8  2.2  .8 1 1.19  .04  .07  .04 1.23                         13.91 .21 13.40                      13.25                                                                .10 .04  .36                         7900      7747  7880
#
# 4
# x: 0.0
# y: 0.0
# z: 22.5
# 80.0
# m: 47.0
# n: 30.0
# --------------------------------------------------------------------------------
# 000024.  +3930   235754.  +3914   112.33 -22.31 333.36  20.33              UGC 12894                     PGC   35    .I..9.. U     10.0  .9             .96  .09  .00  .06 1.00                                                                    15.51 .1                                                       .00 .00  .47  55  4  34  5   329  6             522    35
#
# 5
# 000024.  +1713   235754.  +1657   105.91 -43.95 310.03  17.28              UGC 12893                     PGC   38    .SA.8.. U      8.0  .8            1.23  .06  .01  .06 1.24                         14.6  .3  14.52                                                                                           .01 .00  .07                1108               1262   761
#
# 6
# 000024.  +0750   235754.  +0734   101.69 -52.91 300.50  15.18              UGC 12892                     PGC   39    .SB.2.. U      2.0  .9             .91  .07  .24  .05  .93                         15.40 .18                                                                                                 .30 .12  .19
#
# 7
# 000029.0 -402900 235755.0 -404542 337.93 -73.00 254.11   -.18              ESO  293- 27                  PGC   43    .SBR4*. S      4.0 1.0  5.2  .7 1 1.28  .05  .55  .05 1.29          153            14.36 .21 13.50                                                                                           .81 .28  .03                         3164  34  3135  2921
#
# 8
# x: 0.0
# y: 0.0
# z: 29.0
# 40.0
# m: 29.0
# n: 0.0
# --------------------------------------------------------------------------------
# 000038.0 +200333 2358 4.3 +194651 106.99 -41.23 312.95  17.79              UGC 12895      KUG 2358+197   PGC   53    .S..7.. U      7.0  .9             .90  .07  .09  .08  .91          100                                                                                                                      .13 .05  .10                6752               6912  6409
#
# 9
# x: 0.0
# y: 0.0
# z: 38.0
# 20.0
# m: 3.0
# n: 33.0
# --------------------------------------------------------------------------------
# 000038.3 +282306 2358 4.6 +280624 109.57 -33.17 321.60  19.13              UGC 12897      HICK   99A     PGC   54    .S..2.. U      2.0  .9            1.06  .06  .48  .05 1.07           11 14.84S .15 14.87 .18 14.02 13.77  .35                 17.52 .3                                                 3.26  .59 .24  .16        607  7  8705 10  8705  41  8882  8378
#
# 10
# x: 0.0
# y: 0.0
# z: 38.3
# 28.0
# m: 23.0
# n: 6.0
# --------------------------------------------------------------------------------
# 000036.  +3336   235806.  +3320   110.96 -28.08 327.11  19.77              UGC 12898      KAZ   237      PGC   55    .S..6*. U      6.0 1.3             .96  .17  .39  .12  .98           10                                                                                                                      .58 .20  .18                4778 10            4963  4465
#
# 11
# 000044.3 +282405 235810.6 +280723 109.60 -33.15 321.63  19.12              MCG  5- 1- 21  HICK   99C     PGC   58    .S?....                            .89  .11  .24  .07  .90              15.71S .15 15.37 .18 14.94 14.40  .62                                                                                .35 .12  .16                         8216  41  8393  7889
#
# 12
# x: 0.0
# y: 0.0
# z: 44.3
# 28.0
# m: 24.0
# n: 5.0
# --------------------------------------------------------------------------------
# 000046.8 +282410 235813.1 +280728 109.61 -33.16 321.63  19.11              UGC 12899      HICK   99B     PGC   63    .L?....                            .98  .09  .01  .03 1.00              14.68S .15 14.22 .15 14.16 14.43  .46                                                                                .00      .16                         8870  31  9047  8543
#
# 13
# x: 0.0
# y: 0.0
# z: 46.8
# 28.0
# m: 24.0
# n: 10.0
# --------------------------------------------------------------------------------
# 000052.9 -472118 235819.0 -473800 325.70 -67.48 247.70  -2.67              ESO  193-  9   FAIR  623      PGC   65    RLBR+*/ Sr     -.9  .6            1.07  .05  .55  .03  .99          156            15.13 .21 15.00                                                                                           .00      .04                         5912  34  5859  5701
#
# 14
# x: 0.0
# y: 0.0
# z: 52.9
# 47.0
# m: 21.0
# n: 18.0
# --------------------------------------------------------------------------------
# 000055.9 -404242 235822.0 -405924 337.20 -72.88 253.92   -.34              ESO  293- 29                  PGC   69    .SBT5*. Sr     5.4  .7  2.2 1.3 1 1.02  .05  .26  .05 1.02           17            14.90 .21 14.40                                                                                           .39 .13  .03                        14710     14679 14467
#
# 15
# x: 0.0
# y: 0.0
# z: 55.9
# 40.0
# m: 42.0
# n: 42.0
# --------------------------------------------------------------------------------
# 000054.  +2020   235824.  +2004   107.19 -40.98 313.26  17.76              UGC 12900                     PGC   70    .S..6*. U      6.0 1.4            1.26  .04 1.09  .05 1.29          111            15.50 .18 13.73                                                                                          1.47 .50  .27                6803               6964  6460
#
# 16
# [0.007500000000000001, 0.03625, 0.08875000000000001, 0.09375, 0.12083333333333333, 0.15833333333333333, 0.15958333333333333, 0.18458333333333332, 0.19499999999999998, 0.22041666666666665, 0.23291666666666666]
# [47.27444444444444, -6.374722222222222, -2.6105555555555555, -80.79166666666667, -40.483333333333334, 20.059166666666666, 28.384999999999998, 28.40138888888889, 28.402777777777775, -47.355000000000004, -40.711666666666666]
# [2.39883291901949, 1.5488166189124812, 1.2302687708123818, 1.6982436524617444, 1.9498445997580454, 0.8128305161640993, 1.1748975549395297, 0.7943282347242816, 1.0, 0.9772372209558107, 1.0471285480508996]
