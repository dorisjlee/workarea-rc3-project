# %% [markdown]
# "-t power Increasing the value of power will enhance the contrast between colors; useful when all pixels are close to white, but you wish to accentuate the color difference."

# %%
from IPython.core.display import Image 
Image(filename="169_26_min1s_max.jpg")

# %% [markdown]
#     os.system("mJPEG "+ " -t 1.5  \ "+
# 		" -red "+ "SDSS_frame-"+"i"+"-"+str(run).zfill(6)+"-"+str(camcol)+"-"+str(field).zfill(4)+ "cropped.fits "+ " 1s max gaussian-log \
#         -green  SDSS_frame-"+"r"+"-"+str(run).zfill(6)+"-"+str(camcol)+"-"+str(field).zfill(4)+"cropped.fits "+" 1s max gaussian-log \
#         -blue SDSS_frame-"+"g"+"-"+str(run).zfill(6)+"-"+str(camcol)+"-"+str(field).zfill(4)+"cropped.fits "+ " 2s max gaussian-log \
#         -out "+str(floor(ra))+"_"+str(floor(dec))+"_tcolor_min1s_max.jpg")

# %%
Image(filename="169_26_tcolor_1.5_min1s_max.jpg")

# %% [markdown]
#     os.system("mJPEG "+ " -t 2  \ "+
# 		" -red "+ "SDSS_frame-"+"i"+"-"+str(run).zfill(6)+"-"+str(camcol)+"-"+str(field).zfill(4)+ "cropped.fits "+ " 1s max gaussian-log \
#         -green  SDSS_frame-"+"r"+"-"+str(run).zfill(6)+"-"+str(camcol)+"-"+str(field).zfill(4)+"cropped.fits "+" 1s max gaussian-log \
#         -blue SDSS_frame-"+"g"+"-"+str(run).zfill(6)+"-"+str(camcol)+"-"+str(field).zfill(4)+"cropped.fits "+ " 2s max gaussian-log \
#         -out "+str(floor(ra))+"_"+str(floor(dec))+"_tcolor_min1s_max.jpg")

# %%
Image(filename="169_26_tcolor_2_min1s_max.jpg")

# %%
Image(filename="169_26_tcolor_2.5_min1s_max.jpg")

# %%
Image(filename="169_26_tcolor_4_min1s_max.jpg")

# %% [markdown]
# The contrast is seen much better when power (value for -t flag) is adjusted to 10.

# %%
Image(filename="169_26_tcolor_10_min1s_max.jpg")

# %%
Image(filename="169_26_tcolor_20_min1s_max.jpg")
